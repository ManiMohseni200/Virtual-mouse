# %%
import cv2
import numpy as np
import pyautogui
import os

from mediapipe.python.solutions import hands as mp_hands

# PyAutoGUI Settings
pyautogui.FAILSAFE = False # Prevents program from stopping if you hit a corner
screen_w, screen_h = pyautogui.size() # Gets your monitor resolution

# %% [markdown]
# We don't want the mouse to teleport; we want it to glide. We use a smoothing factor for this.

# %%
# Initialize Tracker
hand_tracker = mp_hands.Hands(
    max_num_hands=1, 
    min_detection_confidence=0.7, 
    min_tracking_confidence=0.7
)

# Parameters
frame_reduction = 100  # Creates a 'margin' so you don't have to reach the camera edges
smooth_factor = 2      # Higher = smoother but slower cursor
plocX, plocY = 0, 0    # Previous locations
clocX, clocY = 0, 0    # Current locations

print(f"Screen Resolution: {screen_w}x{screen_h}")
# Out:
# Screen Resolution: 1920x1080

# %% [markdown]
# # The Global Controller Loop

# %%
# --- Logic State ---
is_pinched = False          # For Single Click/Drag (Thumb + Index)
is_double_pinched = False   # For Double Click (Index + Middle)
plocX, plocY = 0, 0

cap = cv2.VideoCapture(0)

while True:
    success, frame = cap.read()
    if not success: break
    
    frame = cv2.flip(frame, 1)
    h, w, _ = frame.shape
    
    rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    results = hand_tracker.process(rgb)
    
    if results.multi_hand_landmarks:
        lms = results.multi_hand_landmarks[0].landmark
        
        # 1. Get Coordinates
        # Thumb (4), Index (8), Middle (12)
        tx, ty = int(lms[4].x * w), int(lms[4].y * h)
        ix, iy = int(lms[8].x * w), int(lms[8].y * h)
        mx_tip, my_tip = int(lms[12].x * w), int(lms[12].y * h)
        
        # 2. Map Thumb to Screen (Movement)
        mx_screen = np.interp(tx, (frame_reduction, w - frame_reduction), (0, screen_w))
        my_screen = np.interp(ty, (frame_reduction, h - frame_reduction), (0, screen_h))
        
        # 3. Smooth & Move
        clocX = plocX + (mx_screen - plocX) / smooth_factor
        clocY = plocY + (my_screen - plocY) / smooth_factor
        pyautogui.moveTo(clocX, clocY, _pause=False)
        plocX, plocY = clocX, clocY
        
        # 4. Gesture Distances
        dist_click = np.hypot(ix - tx, iy - ty)          # Thumb + Index
        dist_double = np.hypot(mx_tip - ix, my_tip - iy) # Index + Middle
        
        # --- GESTURE 1: Single Click & Drag (Thumb + Index) ---
        if dist_click < 40:
            if not is_pinched:
                pyautogui.mouseDown()
                is_pinched = True
            cv2.circle(frame, (tx, ty), 15, (0, 255, 0), cv2.FILLED) # Green feedback
        else:
            if is_pinched:
                pyautogui.mouseUp()
                is_pinched = False
        
        # --- GESTURE 2: Double Click (Index + Middle) ---
        if dist_double < 40:
            if not is_double_pinched:
                pyautogui.doubleClick()
                is_double_pinched = True
                # Visual feedback for Double Click
                cv2.circle(frame, (ix, iy), 30, (255, 0, 0), cv2.FILLED) # Blue feedback
        else:
            is_double_pinched = False

        # Visual indicator for the "Cursor" (Thumb)
        cv2.circle(frame, (tx, ty), 10, (255, 0, 255), cv2.FILLED)

    cv2.imshow("Multi-Gesture Virtual Mouse", frame)
    if cv2.waitKey(1) & 0xFF == ord('q'): break

# Final Safety Release
pyautogui.mouseUp()
cap.release()
cv2.destroyAllWindows()
# Out:
# C:\Users\manim\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\protobuf\symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
